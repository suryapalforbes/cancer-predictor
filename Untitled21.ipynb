# %% [markdown]
# <a href="https://colab.research.google.com/github/suryapalforbes/cancer-predictor/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/test.txt',sep = ';',header = None,names = ['text','emotion'])

# %%
df
# Out:
#                                                    text  emotion
# 0     im feeling rather rotten so im not very ambiti...        0
# 1             im updating my blog because i feel shitty        0
# 2     i never make her separate from me because i do...        0
# 3     i left with my bouquet of red and yellow tulip...        1
# 4       i was feeling a little vain when i did this one        0
# ...                                                 ...      ...
# 1995  i just keep feeling like someone is being unki...        3
# 1996  im feeling a little cranky negative after this...        3
# 1997  i feel that i am useful to my people and that ...        1
# 1998  im feeling more comfortable with derby i feel ...        1
# 1999  i feel all weird when i have to meet w people ...        2
#
# [2000 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# text       0
# emotion    0
# dtype: int64

# %%
df['text']=df['text'].apply(lambda x:x.lower())

# %%
unique_emotions=df['emotion'].unique()
emotion_numbers={}
i=0
for emo in unique_emotions:
  emotion_numbers[emo]=i
  i +=1
df['emotion']= df['emotion'].map(emotion_numbers)

# %%
df
# Out:
#                                                    text  emotion
# 0     im feeling rather rotten so im not very ambiti...        0
# 1             im updating my blog because i feel shitty        0
# 2     i never make her separate from me because i do...        0
# 3     i left with my bouquet of red and yellow tulip...        1
# 4       i was feeling a little vain when i did this one        0
# ...                                                 ...      ...
# 1995  i just keep feeling like someone is being unki...        3
# 1996  im feeling a little cranky negative after this...        3
# 1997  i feel that i am useful to my people and that ...        1
# 1998  im feeling more comfortable with derby i feel ...        1
# 1999  i feel all weird when i have to meet w people ...        2
#
# [2000 rows x 2 columns]

# %%
import string
def remove_punc(txt):
  return txt .translate(str.maketrans('','',string.punctuation))

# %%
def remove_numbers(txt):
  new=''
  for i in txt:
    if not i.isdigit():
      new+=i
  return new

df['text']= df['text'].apply(remove_numbers)

# %%
def remove_emoji(txt):
  new=''
  for i in txt:
    if i.isascii():
      new+=i
  return new
df['text']=df['text'].apply(remove_emoji)

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words=stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words=stopwords.words('english')
def remove_stopwords(txt):
  return ' '.join([word for word in txt.split() if word not in stop_words])

# %%
df.loc[1]['text']
# Out:
# 'im updating blog feel shitty'

# %%
df['text']=df['text'].apply(remove_stopwords)

# %%
stop_words
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
df.head()
# Out:
#                                                 text  emotion
# 0        im feeling rather rotten im ambitious right        0
# 1                       im updating blog feel shitty        0
# 2    never make separate ever want feel like ashamed        0
# 3  left bouquet red yellow tulips arm feeling sli...        1
# 4                            feeling little vain one        0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df['text'], df['emotion'], test_size=0.2, random_state=42)

print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (1600,)
# Shape of X_test: (400,)
# Shape of y_train: (1600,)
# Shape of y_test: (400,)

# %%
X_test
# Out:
# 1860    feel dirty spending day mk show buddy decided ...
# 353                   could feel breath smell sweet scent
# 1333                                      want feel loved
# 905     felt need write sometimes anxious feelings imp...
# 1289                                  party met girl drew
#                               ...
# 965                   im feeling listless bored something
# 1284                                    feel ashamed type
# 1739    im feeling romantic thought id show easy last ...
# 261     feel frustrated world around lies shattered go...
# 535                                feel like im fond word
# Name: text, Length: 400, dtype: object
